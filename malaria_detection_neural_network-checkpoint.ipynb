# %%
import numpy as np 
import pandas as pd 
import os
print(os.listdir(r"C:\Users\ADITYA\OneDrive\Desktop\important files\ml\tensorflow"))
# Out:
# ['Analyzing Models with TensorBoard-checkpoint.ipynb', 'Analyzing Models with TensorBoard.ipynb', 'basics-checkpoint.ipynb', 'basics.ipynb', 'cat.jpg', 'dog.jpg', 'kagglecatsanddogs_3367a', 'tensorboard']

# %%
import cv2
import matplotlib.pyplot as plt 
import seaborn as sns
import os
from PIL import Image
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import load_img
from keras.utils import np_utils

# %%
parasitized_data = os.listdir(r"C:\Users\ADITYA\OneDrive\Desktop\important files\ml\malaria\cell_images\Parasitized")
print(parasitized_data[:10])
uninfected_data = os.listdir(r"C:\Users\ADITYA\OneDrive\Desktop\important files\ml\malaria\cell_images/Uninfected")
print('\n')
print(uninfected_data[:10])
# Out:
# ['C100P61ThinF_IMG_20150918_144104_cell_162.png', 'C100P61ThinF_IMG_20150918_144104_cell_163.png', 'C100P61ThinF_IMG_20150918_144104_cell_164.png', 'C100P61ThinF_IMG_20150918_144104_cell_165.png', 'C100P61ThinF_IMG_20150918_144104_cell_166.png', 'C100P61ThinF_IMG_20150918_144104_cell_167.png', 'C100P61ThinF_IMG_20150918_144104_cell_168.png', 'C100P61ThinF_IMG_20150918_144104_cell_169.png', 'C100P61ThinF_IMG_20150918_144104_cell_170.png', 'C100P61ThinF_IMG_20150918_144104_cell_171.png']
#
#
# ['C100P61ThinF_IMG_20150918_144104_cell_128.png', 'C100P61ThinF_IMG_20150918_144104_cell_131.png', 'C100P61ThinF_IMG_20150918_144104_cell_144.png', 'C100P61ThinF_IMG_20150918_144104_cell_21.png', 'C100P61ThinF_IMG_20150918_144104_cell_25.png', 'C100P61ThinF_IMG_20150918_144104_cell_34.png', 'C100P61ThinF_IMG_20150918_144104_cell_48.png', 'C100P61ThinF_IMG_20150918_144104_cell_65.png', 'C100P61ThinF_IMG_20150918_144348_cell_108.png', 'C100P61ThinF_IMG_20150918_144348_cell_120.png']

# %%
len(parasitized_data)+len(uninfected_data)
# Out:
# 27560

# %% [markdown]
# # DATA VISUALIZATION

# %%
from matplotlib import font_manager
font_manager.findfont('Noto Sans Tibetan')
# Out:
# C:\Users\ADITYA\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1241: UserWarning: findfont: Font family ['Noto Sans Tibetan'] not found. Falling back to DejaVu Sans.
# C:\Users\ADITYA\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1241: UserWarning: findfont: Font family ['DejaVu Sans'] not found. Falling back to DejaVu Sans.
# C:\Users\ADITYA\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1250: UserWarning: findfont: Could not match :family=DejaVu Sans:style=normal:variant=normal:weight=normal:stretch=normal:size=10.0. Returning C:\Windows\Fonts\GOUDYSTO.TTF.
# 'C:\\Windows\\Fonts\\GOUDYSTO.TTF'

# %% [markdown]
# ## 1. PARASITIZED DATA

# %%
dir=r"C:\Users\ADITYA\OneDrive\Desktop\important files\ml\malaria\cell_images\Parasitized"
plt.figure(figsize = (12,12))
for i in range(4):
    plt.subplot(1, 4, i+1)
    img = cv2.imread(dir + "/" + parasitized_data[i])
    plt.imshow(img)
    plt.title('PARASITIZED : 1')
    plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2. UNINFECTTED DATA

# %%
plt.figure(figsize = (12,12))
for i in range(4):
    plt.subplot(1, 4, i+1)
    img = cv2.imread(r"C:\Users\ADITYA\OneDrive\Desktop\important files\ml\malaria\cell_images/Uninfected" + "/" + uninfected_data[i])
    plt.imshow(img)
    plt.title('UNINFECTED : 0')
    plt.tight_layout()
plt.show()

# %% [markdown]
# #### You can clearly see the difference between the infected and uninfected. You can observe a small parasites inside the cellular image for infected while for the uninfected the cellular image is clean without any parasites.

# %%
data = []
labels = []
for img in parasitized_data:
    try:
        img_read = plt.imread(r"C:\Users\ADITYA\OneDrive\Desktop\important files\ml\malaria\cell_images\Parasitized" + "/" + img)
        img_resize = cv2.resize(img_read, (50, 50))
        img_array = img_to_array(img_resize)
        data.append(img_array)
        labels.append(1)
    except Exception as e:
        pass
for img in uninfected_data:
    try:
        img_read = plt.imread(r"C:\Users\ADITYA\OneDrive\Desktop\important files\ml\malaria\cell_images/Uninfected" + "/" + img)
        img_resize = cv2.resize(img_read, (50, 50))
        img_array = img_to_array(img_resize)
        data.append(img_array)
        labels.append(0)
    except Exception as e:
        pass

# %%
pd.Series(labels).value_counts()
# Out:
# 1    13779
# 0    13779
# dtype: int64

# %%
plt.imshow(data[10])
plt.show()
print(labels[10])
# Out:
# 1

# %%
image_data = np.array(data)
labels = np.array(labels)

# %%
idx = np.arange(image_data.shape[0])
np.random.shuffle(idx)
image_data = image_data[idx]
labels = labels[idx]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(image_data, labels, test_size = 0.2, random_state = 101)

# %%
y_train = np_utils.to_categorical(y_train, num_classes = 2)
y_test = np_utils.to_categorical(y_test, num_classes = 2)

# %%
print(f'SHAPE OF TRAINING IMAGE DATA : {x_train.shape}')
print(f'SHAPE OF TESTING IMAGE DATA : {x_test.shape}')
print(f'SHAPE OF TRAINING LABELS : {y_train.shape}')
print(f'SHAPE OF TESTING LABELS : {y_test.shape}')
# Out:
# SHAPE OF TRAINING IMAGE DATA : (22046, 50, 50, 3)
# SHAPE OF TESTING IMAGE DATA : (5512, 50, 50, 3)
# SHAPE OF TRAINING LABELS : (22046, 2)
# SHAPE OF TESTING LABELS : (5512, 2)

# %% [markdown]
# # BUILDING THE CNN MODEL (without data augmentation)

# %%
import keras
from tensorflow.keras.layers import Dense, Conv2D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.layers import Activation
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras import backend as K

from tensorflow.keras import optimizers

# %%
def CNNbuild(height, width, classes, channels):
    model = Sequential()
    
    inputShape = (height, width, channels)
    chanDim = -1
    
    if K.image_data_format() == 'channels_first':
        inputShape = (channels, height, width)
    model.add(Conv2D(32, (3,3), activation = 'relu', input_shape = inputShape))
    model.add(MaxPooling2D(2,2))
    model.add(BatchNormalization(axis = chanDim))
    model.add(Dropout(0.2))

    model.add(Conv2D(32, (3,3), activation = 'relu'))
    model.add(MaxPooling2D(2,2))
    model.add(BatchNormalization(axis = chanDim))
    model.add(Dropout(0.2))
    
    model.add(Conv2D(32, (3,3), activation = 'relu'))
    model.add(MaxPooling2D(2,2))
    model.add(BatchNormalization(axis = chanDim))
    model.add(Dropout(0.2))

    model.add(Flatten())
    
    model.add(Dense(512, activation = 'relu'))
    model.add(BatchNormalization(axis = chanDim))
    model.add(Dropout(0.5))
    model.add(Dense(classes, activation = 'softmax'))
    
    return model

# %%
#instantiate the model
height = 50
width = 50
classes = 2
channels = 3
model = CNNbuild(height = height, width = width, classes = classes, channels = channels)
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_3 (Conv2D)            (None, 48, 48, 32)        896
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 24, 24, 32)        0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 24, 24, 32)        128
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 24, 24, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 22, 22, 32)        9248
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 11, 11, 32)        0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 11, 11, 32)        128
# ...

# %%
#compile the model
model.compile(loss = 'categorical_crossentropy', optimizer = 'Adam', metrics = ['accuracy'])

# %%
#fit the model onto the dataset
h = model.fit(x_train, y_train, epochs = 5, batch_size = 32)
# Out:
# Epoch 1/5
# 22046/22046 [==============================] - 432s 20ms/sample - loss: 0.4638 - acc: 0.8106
# Epoch 2/5
# 22046/22046 [==============================] - 406s 18ms/sample - loss: 0.2161 - acc: 0.9222
# Epoch 3/5
# 22046/22046 [==============================] - 437s 20ms/sample - loss: 0.1818 - acc: 0.9370
# Epoch 4/5
# 22046/22046 [==============================] - 365s 17ms/sample - loss: 0.1786 - acc: 0.9406
# Epoch 5/5
# 22046/22046 [==============================] - 303s 14ms/sample - loss: 0.1666 - acc: 0.9456

# %%
h.history['acc']
# Out:
# [0.81057787, 0.9221628, 0.93704075, 0.9405788, 0.94561374]

# %%
plt.figure(figsize = (18,8))
plt.plot(range(5), h.history['acc'], label = 'Training Accuracy')
plt.plot(range(5), h.history['loss'], label = 'Taining Loss')
#ax1.set_xticks(np.arange(0, 31, 5))
plt.xlabel("Number of Epoch's")
plt.ylabel('Accuracy/Loss Value')
plt.title('Training Accuracy and Training Loss')
plt.legend(loc = "best")

# %%
#evaluate the model on test data
predictions = model.evaluate(x_test, y_test)
# Out:
# 5512/5512 [==============================] - 20s 4ms/sample - loss: 0.1442 - acc: 0.9528

# %%
print(f'LOSS : {predictions[0]}')
print(f'ACCURACY : {predictions[1]}')
# Out:
# LOSS : 0.14423965339390737
# ACCURACY : 0.9528301954269409

# %% [markdown]
# ### WITH DATA AUGMENTATION

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen = ImageDataGenerator(rescale = 1/255.,
                                  horizontal_flip = True,
                                  width_shift_range = 0.2,
                                  height_shift_range = 0.2,
                                  fill_mode = 'nearest',
                                  zoom_range = 0.3,
                                  rotation_range = 30)
val_datagen = ImageDataGenerator(rescale = 1/255.)

train_generator = train_datagen.flow(x_train, y_train, batch_size = 64, shuffle = False)
val_generator = val_datagen.flow(x_test, y_test, batch_size = 64, shuffle = False)

# %%
#calling the same model as above
model_aug = CNNbuild(height = height, width = width, classes = classes, channels = channels)

# %%
#compile the model
optim = optimizers.Adam(lr = 0.001, decay = 0.001 / 64)
model_aug.compile(loss = 'categorical_crossentropy', optimizer = optim, metrics = ['accuracy'])

# %%
#fit the model on the augmented dataset
h_aug = model_aug.fit_generator(train_generator, steps_per_epoch = len(x_train) // 64, epochs = 1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-110-cff09c76eab1> in <module>
#       1 #fit the model on the augmented dataset
# ----> 2 h_aug = model_aug.fit_generator(train_generator, steps_per_epoch = len(x_train) // 64, epochs = 1)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1431         shuffle=shuffle,
#    1432         initial_epoch=initial_epoch,
# -> 1433         steps_name='steps_per_epoch')
#    1434
#    1435   def evaluate_generator(self,
#
# ...
